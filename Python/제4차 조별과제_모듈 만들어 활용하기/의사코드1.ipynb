# %% [markdown]
# # **의사코드 1**
#
# 자연어에 가까운 의사코드

# %% [markdown]
# ## 공학용계산기
#
# ```
# # 라이브러리 math를 import한다.
#
# # error = error 변수를 만들고 초기값을 지정한다.
#
# # 사칙연산
#
# 덧셈은 숫자 2개를 더한다.
# 뺄셈은 숫자 2개를 입력받은 순서대로 뺀다.
# 곱셈은 숫자 2개를 곱한다.
# 나눗셈은 숫자 2개를 입력받은 순서대로 나눈다. (2번째 숫자가 분모)
#
# # 삼각함수
#
# 입력받은 두 수를 비교한다. 두 수 중 큰 수로 sin함수 값을 구한다.
# 입력받은 두 수를 비교한다. 입력받은 두 수 중 큰 수로 cos함수 값을 구한다.
# 입력받은 두 수를 비교한다. 입력받은 두 수 중 큰 수로 tan함수 값을 구한다.
#
# # 로그함수 (log 조건 : 밑은 0보다 크고, 1이면 안 되며, 진수는 0보다 커야 한다.)
#
# 로그함수 조건들을 지키면서,
# 입력받은 두 수 중 앞에 있는 숫자를 밑으로 하는 로그함수 값을 구한다.
#
# ```

# %% [markdown]
# ## 호출
#
# ```
# drive 마운트를 한다.
#
# 실행할 파일의 경로를 지정해준다.
#
# 호출.ipynb 와 공학용계산기.ipynb 를 동일한 경로에 있는지 확인한다.
#
# import_ipynb 설치 후, import한다.
#
# 라이브러리 math를 import한다.
#
# 공학용계산기 모듈을 import한다.
#
# 실수 2개를 입력받는다.
#
# 연산한다.
#
# ```

# %% [markdown]
# > 리뷰
#
# *의사코드부터 사용자정의 모듈을 가져오는 방법은 작성하지 않아도 되었을 것 같습니다. (하지만 정리가 잘되어 있어서 개인적으로는 잘 참고했습니다^^)
