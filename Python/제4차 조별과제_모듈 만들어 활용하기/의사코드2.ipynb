# %% [markdown]
# # **의사코드 2**
#
# 자연어와 파이썬 코드 중간 수준 의사코드

# %% [markdown]
# ## 공학용계산기
#
# ```
# # 라이브러리 math를 import한다.
# import math as m
#
# # error = error 변수를 만들고 초기값을 지정한다.
#
# # 사칙연산
#
# def add(x, y):
#   숫자 2개를 더한 값을 반환한다.
#
# def sub(x, y):
#   숫자 2개를 입력받은 순서대로 뺀 값을 반환한다.
#
# def mul(x, y):
#   숫자 2개를 곱한 값을 반환한다.
#
# def div(x, y):
#   if y 값이 0이라면,
#     error을 반환한다.
#   else:
#     숫자 2개를 입력받은 순서대로 나눈 값을 반환한다.
#
#
# # 삼각함수
#
# def sin(x, y):
#   if y가 x보다 크거나 같다면,
#     y의 sin함수 값을 구한다.
#   elif x가 y보다 크다면,
#     x의 sin함수 값을 구한다.
#   else:
#     그 외의 경우는 error를 반환한다.
#
# def cos(x1, x2):
#   if y가 x보다 크거나 같다면,
#     y의 cos함수 값을 구한다.
#   elif x가 y보다 크다면,
#     x의 cos함수 값을 구한다.
#   else:
#     그 외의 경우는 error를 반환한다.
#
# def tan(x1, x2):
#   if y가 x보다 크거나 같다면,
#     x2의 tan함수 값을 구한다.
#   elif x가 y보다 크다면,
#     x1의 tan함수 값을 구한다.
#   else:
#     그 외의 경우는 error를 반환한다.
#
#
# #로그함수
#
# def log(x, y): # x1 = 밑, x2 = 진수
#   if x가 0보다 작거나 같다면,
#     error 값을 반환한다.
#   elif x가 1이라면,
#     error 값을 반환한다.
#   elif y가 0보다 작거나 같다면,
#     error 값을 반환한다.
#   else:
#     앞 숫자가 밑임을 표시하며, 로그함수 값을 반환한다.
#
# ```

# %% [markdown]
# ## 호출
#
# ```
# drive 마운트를 한다.
#
# 실행할 파일의 경로를 지정해준다.
#
# 호출.ipynb 와 공학용계산기.ipynb 를 동일한 경로에 있는지 확인한다.
#
# import_ipynb 설치 후, import한다.
#
# 라이브러리 math를 import한다.
#
# 공학용계산기 모듈을 import한다.
#
# x, y에 실수 2개를 입력받는다.
#
# 연산한다.
#
# ```
