# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/class7/과제/제4차 조별과제/(온) 이호진, 임서연

# %%
# !ls

# %%
# !pip install import_ipynb
import import_ipynb

import math

import 공학용계산기 as c

# %%
print("계산기를 시작하겠습니다.\n")
x, y = map(float, input("숫자 2개를 적어주세요 (띄어쓰기로 구분) : ").split())

# 사칙연산 테스트
print("\n< 사칙연산 >\n")
print("덧셈 : ", c.add(x, y))
print("뺄셈 : ", c.sub(x, y))
print("곱셈 : ", c.mul(x, y))
print("나눗셈 : ", c.div(x, y))

# 삼각함수 테스트
print("\n< 삼각함수 >\n")
print("sin함수 : ", c.sin(x, y))
print("cos함수 : ", c.cos(x, y))
print("tan함수 : ", c.tan(x, y))

# 로그함수 테스트
print("\n< 로그함수 >\n")
print("log함수 : ", c.log(x,y), "\n")

print("-"*60)

# 삼각함수에 넣을 숫자 순서를 바꾼다면? (큰 수를 변수로 받았는지 확인)

print("\n\n큰 수가 제대로 삼각함수에 들어갔는지 확인해 봅시다.")
x, y = map(float, input("\n숫자 2개 순서를 바꿔서 적어주세요 (띄어쓰기로 구분) : ").split())

print("\n< 삼각함수 >\n")
print("sin함수 : ", c.sin(x, y))
print("cos함수 : ", c.cos(x, y))
print("tan함수 : ", c.tan(x, y))

print("\n위에서 구한 삼각함수 값과 똑같나요?\n\n")

print("-"*60)

# 로그함수 조건을 지키지 않는다면?
print("\n\n< 로그함수 조건 >\n\n1. 밑은 0보다 크고 1이면 안된다. \n2. 진수는 0보다 커야 한다.\n")

x, y = map(float, input("\n로그함수 조건에 어긋난 숫자를 포함하여 2개를 적어주세요 (띄어쓰기로 구분) : ").split())

print("\nlog함수 : ", c.log(x,y), "\n")
# Out:
# 계산기를 시작하겠습니다.
#
# 숫자 2개를 적어주세요 (띄어쓰기로 구분) : 10 20
#
# < 사칙연산 >
#
# 덧셈 :  30.0
# 뺄셈 :  -10.0
# 곱셈 :  200.0
# 나눗셈 :  0.5
#
# < 삼각함수 >
#
# sin함수 :  0.9129452507276277
# cos함수 :  0.40808206181339196
# tan함수 :  2.237160944224742
#
# < 로그함수 >
#
# log함수 :  ('앞에 있는 숫자가 밑입니다: ', 1.301029995663981)
#
# ------------------------------------------------------------
#
#
# 큰 수가 제대로 삼각함수에 들어갔는지 확인해 봅시다.
#
# 숫자 2개 순서를 바꿔서 적어주세요 (띄어쓰기로 구분) : 20 10
#
# < 삼각함수 >
#
# sin함수 :  0.9129452507276277
# cos함수 :  0.40808206181339196
# tan함수 :  2.237160944224742
#
# 위에서 구한 삼각함수 값과 똑같나요?
#
#
# ------------------------------------------------------------
#
#
# < 로그함수 조건 >
#
# 1. 밑은 0보다 크고 1이면 안된다.
# 2. 진수는 0보다 커야 한다.
#
#
# 로그함수 조건에 어긋난 숫자를 포함하여 2개를 적어주세요 (띄어쓰기로 구분) : 1 10
#
# log함수 :  error
